# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import requests
import json
from pprint import pprint

import scipy.stats as stats

#from census import Census

#Need api file

# %%
# import housing file
US_housing_file = "Housing Prices for US.csv"
US_housing_data = pd.read_csv(US_housing_file)
US_housing_data.head()
# Out:
#         DATE  MSPUS
# 0   1/1/1963  17800
# 1   4/1/1963  18000
# 2   7/1/1963  17900
# 3  10/1/1963  18500
# 4   1/1/1964  18500

# %%
US_housing= US_housing_data.rename(columns={"MSPUS":"Avg Home Price","DATE":"Date (Quarterly)"})
US_housing.head()
# Out:
#   Date (Quarterly)  Avg Home Price
# 0         1/1/1963           17800
# 1         4/1/1963           18000
# 2         7/1/1963           17900
# 3        10/1/1963           18500
# 4         1/1/1964           18500

# %%
# plot graph of housing prices

plt.rcParams["figure.figsize"]=[20,10]
plt.rcParams["font.size"]=16

fig1, ax1 = plt.subplots()

ax1.set_xlabel("Date (Quarters)")
ax1.set_ylabel("Avg Home Prices")

data1 = US_housing["Avg Home Price"]
x_axis1 = US_housing["Date (Quarterly)"]

cost_trend = plt.plot(x_axis1,data1,color='g',marker = "o")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Import data from FRED

# https://api.stlouisfed.org/fred/series/observations?series_id=GNPCA&api_key=abcdefghijklmnopqrstuvwxyz123456
FRED_url = "https://api.stlouisfed.org/fred/series/observations?series_id="

housing_US_seriesid = "MSPUS"
housing_south_seriesid = "ASPS"
housing_west_seriesid = "ASPW"
housing_northeast_seriesid = "ASPNE"
housing_midwest_seriesid = "ASPMW"

fedfund_seriesid = "FEDFUNDS"

#set the data frequency (d=daily,w=weekly,m=monthly,a=annually)
frequency = "a"

# How will data be summarized (avg, sum, eop=end of period, default is avg)
aggregation = "avg"

api_key = "fd8c22bb4ce3ecd6d465947f86b42594"

query_url_housing = f'{FRED_url}{housing_US_seriesid}&api_key={api_key}&file_type=json'
query_url_south = f'{FRED_url}{housing_south_seriesid}&api_key={api_key}&file_type=json'
query_url_west = f'{FRED_url}{housing_west_seriesid}&api_key={api_key}&file_type=json'
query_url_northeast = f'{FRED_url}{housing_northeast_seriesid}&api_key={api_key}&file_type=json'
query_url_midwest = f'{FRED_url}{housing_midwest_seriesid}&api_key={api_key}&file_type=json'

# %%
US_housing_response = requests.get(query_url_housing).json()
pprint(US_housing_response)
# Out:
# {'count': 223,
#  'file_type': 'json',
#  'limit': 100000,
#  'observation_end': '9999-12-31',
#  'observation_start': '1600-01-01',
#  'observations': [{'date': '1963-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '17800'},
#                   {'date': '1963-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '18000'},
#                   {'date': '1963-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '17900'},
#                   {'date': '1963-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '18500'},
#                   {'date': '1964-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '18500'},
#                   {'date': '1964-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '18900'},
#                   {'date': '1964-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '18900'},
#                   {'date': '1964-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '19400'},
#                   {'date': '1965-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '20200'},
#                   {'date': '1965-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '19800'},
#                   {'date': '1965-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '20200'},
#                   {'date': '1965-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '20300'},
#                   {'date': '1966-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '21000'},
#                   {'date': '1966-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '22100'},
#                   {'date': '1966-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '21500'},
#                   {'date': '1966-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '21400'},
#                   {'date': '1967-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '22300'},
#                   {'date': '1967-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '23300'},
#                   {'date': '1967-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '22500'},
#                   {'date': '1967-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '22900'},
#                   {'date': '1968-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '23900'},
#                   {'date': '1968-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '24900'},
#                   {'date': '1968-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '24800'},
#                   {'date': '1968-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25600'},
#                   {'date': '1969-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25700'},
#                   {'date': '1969-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25900'},
#                   {'date': '1969-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25900'},
#                   {'date': '1969-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '24900'},
#                   {'date': '1970-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '23900'},
#                   {'date': '1970-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '24400'},
#                   {'date': '1970-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '23000'},
#                   {'date': '1970-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '22600'},
#                   {'date': '1971-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '24300'},
#                   {'date': '1971-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25800'},
#                   {'date': '1971-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25300'},
#                   {'date': '1971-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '25500'},
#                   {'date': '1972-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '26200'},
#                   {'date': '1972-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '26800'},
#                   {'date': '1972-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '27900'},
#                   {'date': '1972-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '29200'},
#                   {'date': '1973-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '30200'},
#                   {'date': '1973-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '32700'},
#                   {'date': '1973-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '33500'},
#                   {'date': '1973-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '34000'},
#                   {'date': '1974-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '35200'},
#                   {'date': '1974-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '35600'},
#                   {'date': '1974-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '36200'},
#                   {'date': '1974-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '37200'},
#                   {'date': '1975-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '38100'},
#                   {'date': '1975-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '39000'},
#                   {'date': '1975-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '38800'},
#                   {'date': '1975-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '41200'},
#                   {'date': '1976-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '42800'},
#                   {'date': '1976-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '44200'},
#                   {'date': '1976-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '44400'},
#                   {'date': '1976-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '45500'},
#                   {'date': '1977-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '46300'},
#                   {'date': '1977-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '48900'},
#                   {'date': '1977-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '48800'},
#                   {'date': '1977-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '51600'},
#                   {'date': '1978-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '53000'},
#                   {'date': '1978-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '55300'},
#                   {'date': '1978-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '56100'},
#                   {'date': '1978-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '59000'},
#                   {'date': '1979-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '60600'},
#                   {'date': '1979-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '63100'},
#                   {'date': '1979-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '64700'},
#                   {'date': '1979-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '62600'},
#                   {'date': '1980-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '63700'},
#                   {'date': '1980-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '64000'},
#                   {'date': '1980-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '64900'},
#                   {'date': '1980-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '66400'},
#                   {'date': '1981-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '66800'},
#                   {'date': '1981-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '69400'},
#                   {'date': '1981-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '69200'},
#                   {'date': '1981-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '70400'},
#                   {'date': '1982-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '66400'},
#                   {'date': '1982-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '69600'},
#                   {'date': '1982-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '69300'},
#                   {'date': '1982-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '71600'},
#                   {'date': '1983-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '73300'},
#                   {'date': '1983-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '74900'},
#                   {'date': '1983-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '77400'},
#                   {'date': '1983-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '75900'},
#                   {'date': '1984-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '78200'},
#                   {'date': '1984-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '80700'},
#                   {'date': '1984-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '81000'},
#                   {'date': '1984-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '79900'},
#                   {'date': '1985-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '82800'},
#                   {'date': '1985-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '84300'},
#                   {'date': '1985-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '83200'},
#                   {'date': '1985-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '86800'},
#                   {'date': '1986-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '88000'},
#                   {'date': '1986-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '92100'},
#                   {'date': '1986-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '93000'},
#                   {'date': '1986-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '95000'},
#                   {'date': '1987-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '97900'},
#                   {'date': '1987-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '103400'},
#                   {'date': '1987-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '106000'},
#                   {'date': '1987-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '111500'},
#                   {'date': '1988-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '110000'},
#                   {'date': '1988-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '110000'},
#                   {'date': '1988-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '115000'},
#                   {'date': '1988-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '113900'},
#                   {'date': '1989-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '118000'},
#                   {'date': '1989-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '118900'},
#                   {'date': '1989-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1989-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '124800'},
#                   {'date': '1990-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '123900'},
#                   {'date': '1990-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '126800'},
#                   {'date': '1990-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '117000'},
#                   {'date': '1990-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '121500'},
#                   {'date': '1991-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1991-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '119900'},
#                   {'date': '1991-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1991-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1992-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '119500'},
#                   {'date': '1992-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1992-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '120000'},
#                   {'date': '1992-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '126000'},
#                   {'date': '1993-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '125000'},
#                   {'date': '1993-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '127000'},
#                   {'date': '1993-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '127000'},
#                   {'date': '1993-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '127000'},
#                   {'date': '1994-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '130000'},
#                   {'date': '1994-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '130000'},
#                   {'date': '1994-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '129700'},
#                   {'date': '1994-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '132000'},
#                   {'date': '1995-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '130000'},
#                   {'date': '1995-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '133900'},
#                   {'date': '1995-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '132000'},
#                   {'date': '1995-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '138000'},
#                   {'date': '1996-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '137000'},
#                   {'date': '1996-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '139900'},
#                   {'date': '1996-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '140000'},
#                   {'date': '1996-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '144100'},
#                   {'date': '1997-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '145000'},
#                   {'date': '1997-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '145800'},
#                   {'date': '1997-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '145000'},
#                   {'date': '1997-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '144200'},
#                   {'date': '1998-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '152200'},
#                   {'date': '1998-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '149500'},
#                   {'date': '1998-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '153000'},
#                   {'date': '1998-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '153000'},
#                   {'date': '1999-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '157400'},
#                   {'date': '1999-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '158700'},
#                   {'date': '1999-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '159100'},
#                   {'date': '1999-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '165300'},
#                   {'date': '2000-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '165300'},
#                   {'date': '2000-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '163200'},
#                   {'date': '2000-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '168800'},
#                   {'date': '2000-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '172900'},
#                   {'date': '2001-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '169800'},
#                   {'date': '2001-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '179000'},
#                   {'date': '2001-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '172500'},
#                   {'date': '2001-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '171100'},
#                   {'date': '2002-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '188700'},
#                   {'date': '2002-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '187200'},
#                   {'date': '2002-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '178100'},
#                   {'date': '2002-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '190100'},
#                   {'date': '2003-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '186000'},
#                   {'date': '2003-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '191800'},
#                   {'date': '2003-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '191900'},
#                   {'date': '2003-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '198800'},
#                   {'date': '2004-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '212700'},
#                   {'date': '2004-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '217600'},
#                   {'date': '2004-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '213500'},
#                   {'date': '2004-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '228800'},
#                   {'date': '2005-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '232500'},
#                   {'date': '2005-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '233700'},
#                   {'date': '2005-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '236400'},
#                   {'date': '2005-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '243600'},
#                   {'date': '2006-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '247700'},
#                   {'date': '2006-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '246300'},
#                   {'date': '2006-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '235600'},
#                   {'date': '2006-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '245400'},
#                   {'date': '2007-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '257400'},
#                   {'date': '2007-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '242200'},
#                   {'date': '2007-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '241800'},
#                   {'date': '2007-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '238400'},
#                   {'date': '2008-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '233900'},
#                   {'date': '2008-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '235300'},
#                   {'date': '2008-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '226500'},
#                   {'date': '2008-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '222500'},
#                   {'date': '2009-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '208400'},
#                   {'date': '2009-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '220900'},
#                   {'date': '2009-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '214300'},
#                   {'date': '2009-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '219000'},
#                   {'date': '2010-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '222900'},
#                   {'date': '2010-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '219500'},
#                   {'date': '2010-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '224100'},
#                   {'date': '2010-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '224300'},
#                   {'date': '2011-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '226900'},
#                   {'date': '2011-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '228100'},
#                   {'date': '2011-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '223500'},
#                   {'date': '2011-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '221100'},
#                   {'date': '2012-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '238400'},
#                   {'date': '2012-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '238700'},
#                   {'date': '2012-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '248800'},
#                   {'date': '2012-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '251700'},
#                   {'date': '2013-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '258400'},
#                   {'date': '2013-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '268100'},
#                   {'date': '2013-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '264800'},
#                   {'date': '2013-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '273600'},
#                   {'date': '2014-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '275200'},
#                   {'date': '2014-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '288000'},
#                   {'date': '2014-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '281000'},
#                   {'date': '2014-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '298900'},
#                   {'date': '2015-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '289200'},
#                   {'date': '2015-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '289100'},
#                   {'date': '2015-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '295800'},
#                   {'date': '2015-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '302500'},
#                   {'date': '2016-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '299800'},
#                   {'date': '2016-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '306000'},
#                   {'date': '2016-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '303800'},
#                   {'date': '2016-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '310900'},
#                   {'date': '2017-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '313100'},
#                   {'date': '2017-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '318200'},
#                   {'date': '2017-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '320500.0'},
#                   {'date': '2017-10-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '337900.0'},
#                   {'date': '2018-01-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '331800.0'},
#                   {'date': '2018-04-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '315600.0'},
#                   {'date': '2018-07-01',
#                    'realtime_end': '2018-11-06',
#                    'realtime_start': '2018-11-06',
#                    'value': '325200.0'}],
#  'offset': 0,
#  'order_by': 'observation_date',
#  'output_type': 1,
#  'realtime_end': '2018-11-06',
#  'realtime_start': '2018-11-06',
#  'sort_order': 'asc',
#  'units': 'lin'}

# %%
US_housing_date=[]
US_housing_cost=[]

len(US_housing_response["observations"])

for observation in US_housing_response["observations"]:
    US_housing_date.append(observation["date"])
    US_housing_date_pd=pd.DataFrame(US_housing_date, columns=["Date"])
    US_housing_cost.append(observation["value"])
    US_housing_cost_pd=pd.DataFrame(US_housing_cost,columns=["Avg US Housing Cost"])

US_housing_df = pd.concat([US_housing_date_pd,US_housing_cost_pd], axis=1)
US_housing_df.head()
# Out:
#          Date Avg US Housing Cost
# 0  1963-01-01               17800
# 1  1963-04-01               18000
# 2  1963-07-01               17900
# 3  1963-10-01               18500
# 4  1964-01-01               18500

# %%
# pull in region data 

south_housing_response = requests.get(query_url_south).json()
west_housing_response = requests.get(query_url_west).json()
northeast_housing_response = requests.get(query_url_northeast).json()
midwest_housing_response = requests.get(query_url_midwest).json()

# %%
# South DF
south_housing_date=[]
south_housing_cost=[]

for observation in south_housing_response["observations"]:
    south_housing_date.append(observation["date"])
    south_housing_date_pd=pd.DataFrame(south_housing_date, columns=["Date"])
    south_housing_cost.append(observation["value"])
    south_housing_cost_pd=pd.DataFrame(south_housing_cost,columns=["Avg South Region Housing Cost"])

south_housing_df = pd.concat([south_housing_date_pd,south_housing_cost_pd], axis=1)
south_housing_df.head()
# Out:
#          Date Avg South Region Housing Cost
# 0  1975-01-01                         38000
# 1  1975-04-01                         39800
# 2  1975-07-01                         39200
# 3  1975-10-01                         41300
# 4  1976-01-01                         43000

# %%
# South DF
west_housing_date=[]
west_housing_cost=[]

for observation in west_housing_response["observations"]:
    west_housing_date.append(observation["date"])
    west_housing_date_pd=pd.DataFrame(west_housing_date, columns=["Date"])
    west_housing_cost.append(observation["value"])
    west_housing_cost_pd=pd.DataFrame(west_housing_cost,columns=["Avg West Region Housing Cost"])

west_housing_df = pd.concat([west_housing_date_pd,west_housing_cost_pd], axis=1)
west_housing_df.head()
# Out:
#          Date Avg West Region Housing Cost
# 0  1975-01-01                        42300
# 1  1975-04-01                        43600
# 2  1975-07-01                        43600
# 3  1975-10-01                        47400
# 4  1976-01-01                        49200

# %%
# NE DF
ne_housing_date=[]
ne_housing_cost=[]

for observation in northeast_housing_response["observations"]:
    ne_housing_cost.append(observation["value"])
    ne_housing_cost_pd=pd.DataFrame(west_housing_cost,columns=["Avg NE Region Housing Cost"])

ne_housing_df = pd.concat([west_housing_date_pd,ne_housing_cost_pd], axis=1)
ne_housing_df.head()
# Out:
#          Date Avg NE Region Housing Cost
# 0  1975-01-01                      42300
# 1  1975-04-01                      43600
# 2  1975-07-01                      43600
# 3  1975-10-01                      47400
# 4  1976-01-01                      49200

# %%
# MW DF
mw_housing_date=[]
mw_housing_cost=[]

for observation in midwest_housing_response["observations"]:
    mw_housing_cost.append(observation["value"])
    mw_housing_cost_pd=pd.DataFrame(mw_housing_cost,columns=["Avg MW Region Housing Cost"])

mw_housing_df = pd.concat([west_housing_date_pd,mw_housing_cost_pd], axis=1)
mw_housing_df.head()
# Out:
#          Date Avg MW Region Housing Cost
# 0  1975-01-01                      41800
# 1  1975-04-01                      44000
# 2  1975-07-01                      42900
# 3  1975-10-01                      44500
# 4  1976-01-01                      45100

# %%
regional_housing = pd.concat([south_housing_date_pd,south_housing_cost_pd,west_housing_cost_pd,ne_housing_cost_pd,mw_housing_cost_pd],axis=1)
regional_housing
# Out:
#            Date Avg South Region Housing Cost Avg West Region Housing Cost  \
# 0    1975-01-01                         38000                        42300
# 1    1975-04-01                         39800                        43600
# 2    1975-07-01                         39200                        43600
# 3    1975-10-01                         41300                        47400
# 4    1976-01-01                         43000                        49200
# 5    1976-04-01                         43700                        51600
# 6    1976-07-01                         44200                        52000
# 7    1976-10-01                         44200                        54900
# 8    1977-01-01                         45100                        57900
# 9    1977-04-01                         48300                        61200
# 10   1977-07-01                         48300                        60700
# 11   1977-10-01                         50400                        65300
# 12   1978-01-01                         52400                        66800
# 13   1978-04-01                         54800                        69600
# 14   1978-07-01                         56800                        70000
# 15   1978-10-01                         58600                        76200
# 16   1979-01-01                         60900                        77000
# 17   1979-04-01                         64000                        82000
# 18   1979-07-01                         66300                        86300
# 19   1979-10-01                         62900                        86200
# 20   1980-01-01                         65800                        86800
# 21   1980-04-01                         66800                        90000
# 22   1980-07-01                         71300                        87600
# 23   1980-10-01                         72500                        95100
# 24   1981-01-01                         72500                        92400
# 25   1981-04-01                         75900                        97100
# 26   1981-07-01                         77800                        97400
# 27   1981-10-01                         77600                        97400
# 28   1982-01-01                         76000                        92100
# 29   1982-04-01                         79800                        96300
# ..          ...                           ...                          ...
# 145  2011-04-01                        244200                       311000
# 146  2011-07-01                        247500                       294700
# 147  2011-10-01                        236100                       298200
# 148  2012-01-01                        254600                       319000
# 149  2012-04-01                        253000                       313400
# 150  2012-07-01                        269400                       313900
# 151  2012-10-01                        275800                       325900
# 152  2013-01-01                        273100                       342900
# 153  2013-04-01                        295100                       355000
# 154  2013-07-01                        292600                       372200
# 155  2013-10-01                        292100                       413200
# 156  2014-01-01                        297100                       400800
# 157  2014-04-01                        310200                       391200
# 158  2014-07-01                        297100                       393200
# 159  2014-10-01                        332500                       420600
# 160  2015-01-01                        309000                       408700
# 161  2015-04-01                        306300                       391100
# 162  2015-07-01                        312200                       409600
# 163  2015-10-01                        324200                       427200
# 164  2016-01-01                        330300                       414500
# 165  2016-04-01                        314400                       439600
# 166  2016-07-01                        315700                       437100
# 167  2016-10-01                        325200                       438500
# 168  2017-01-01                        327200                       434700
# 169  2017-04-01                        336100                       432700
# 170  2017-07-01                      334000.0                     451400.0
# 171  2017-10-01                      340400.0                     486800.0
# 172  2018-01-01                      329900.0                     456800.0
# 173  2018-04-01                      327200.0                     483700.0
# 174  2018-07-01                      338700.0                     462000.0
#
#     Avg NE Region Housing Cost Avg MW Region Housing Cost
# 0                        42300                      41800
# 1                        43600                      44000
# 2                        43600                      42900
# 3                        47400                      44500
# 4                        49200                      45100
# 5                        51600                      49400
# 6                        52000                      47800
# 7                        54900                      52600
# 8                        57900                      51500
# 9                        61200                      54100
# 10                       60700                      54800
# 11                       65300                      60900
# 12                       66800                      59600
# 13                       69600                      63400
# 14                       70000                      66000
# 15                       76200                      68400
# 16                       77000                      66200
# 17                       82000                      75800
# 18                       86300                      73700
# 19                       86200                      76100
# 20                       86800                      73300
# 21                       90000                      73600
# 22                       87600                      74400
# 23                       95100                      76600
# 24                       92400                      88600
# 25                       97100                      82700
# 26                       97400                      78900
# 27                       97400                      78800
# 28                       92100                      86100
# 29                       96300                      84200
# ..                         ...                        ...
# 145                     311000                     247500
# 146                     294700                     230400
# 147                     298200                     248200
# 148                     319000                     254300
# 149                     313400                     261000
# 150                     313900                     271700
# 151                     325900                     259000
# 152                     342900                     270300
# 153                     355000                     289600
# 154                     372200                     305700
# 155                     413200                     317900
# 156                     400800                     299000
# 157                     391200                     305700
# 158                     393200                     309600
# 159                     420600                     312400
# 160                     408700                     320200
# 161                     391100                     325300
# 162                     409600                     302000
# 163                     427200                     313600
# 164                     414500                     303800
# 165                     439600                     296500
# 166                     437100                     312500
# 167                     438500                     335200
# 168                     434700                     329200
# 169                     432700                     322300
# 170                   451400.0                   316500.0
# 171                   486800.0                   322800.0
# 172                   456800.0                   326300.0
# 173                   483700.0                   316600.0
# 174                   462000.0                   343000.0
#
# [175 rows x 5 columns]

# %%
# plot graph of housing prices by region

fig2, ax2 = plt.subplots()

ax2.set_xlabel("Date (Quarters)")
ax2.set_ylabel("Avg Home Prices")

data_west = regional_housing["Avg West Region Housing Cost"]
data_south = regional_housing["Avg South Region Housing Cost"]
data_ne = regional_housing["Avg NE Region Housing Cost"]
data_mw = regional_housing["Avg MW Region Housing Cost"]

x_axis2 = regional_housing["Date"]

west_trend = plt.plot(x_axis2,data_west,color='g',marker = "o",label="West")
south_trend = plt.plot(x_axis2,data_south,color='r',marker = "o")
ne_trend = plt.plot(x_axis2,data_ne,color='b',marker = "o")
mw_trend = plt.plot(x_axis2,data_mw,color='c',marker = "o")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# ANOVA between regions
# chi-squared test between regions

# %%
# call data from csv

# import housing file
regional_housing_file = "Housing prices by region.csv"
regional_housing_data = pd.read_csv(regional_housing_file)
regional_housing_data.head()
# Out:
#         DATE  ASPNE  ASPMW   ASPW   ASPS
# 0   1/1/1975  47300  41800  42300  38000
# 1   4/1/1975  46400  44000  43600  39800
# 2   7/1/1975  47400  42900  43600  39200
# 3  10/1/1975  47700  44500  47400  41300
# 4   1/1/1976  48600  45100  49200  43000

# %%
regional_housing= regional_housing_data.rename(columns={"DATE":"Date (Quarterly)","ASPS":"South","ASPW":"West","ASPNE":"Northeast","ASPMW":"Midwest"})
regional_housing.head()
# Out:
#   Date (Quarterly)  Northeast  Midwest   West  South
# 0         1/1/1975      47300    41800  42300  38000
# 1         4/1/1975      46400    44000  43600  39800
# 2         7/1/1975      47400    42900  43600  39200
# 3        10/1/1975      47700    44500  47400  41300
# 4         1/1/1976      48600    45100  49200  43000

# %%
# plot graph of housing prices by region

plt.rcParams["figure.figsize"]=[20,10]
plt.rcParams["font.size"]=16

fig3, ax3 = plt.subplots()

ax3.set_xlabel("Date (Quarters)")
ax3.set_ylabel("Avg Home Prices")

data_west = regional_housing["West"]
data_south = regional_housing["South"]
data_ne = regional_housing["Northeast"]
data_mw = regional_housing["Midwest"]

x_axis3 = regional_housing["Date (Quarterly)"]

west_trend = plt.plot(x_axis3,data_west,color='g',marker = "o")
south_trend = plt.plot(x_axis3,data_south,color='r',marker = "o")
ne_trend = plt.plot(x_axis3,data_ne,color='b',marker = "o")
mw_trend = plt.plot(x_axis3,data_mw,color='c',marker = "o")

plt.legend(loc="best")

ax3.grid(True)
fig3.autofmt_xdate()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Perform the ANOVA
stats.f_oneway(regional_housing["West"], regional_housing["South"], regional_housing["Northeast"], regional_housing["Midwest"])
# Out:
# F_onewayResult(statistic=27.70093650654343, pvalue=6.249977134312744e-17)

# %%
regional_20yr = regional_housing.iloc[95:175,:]
regional_20yr.head()

regional_10yr = regional_housing.iloc[135:175,:]
regional_10yr.head()
# Out:
#     Date (Quarterly)  Northeast  Midwest    West   South
# 135        10/1/2008     395100   243800  358400  234500
# 136         1/1/2009     370600   219600  311000  234500
# 137         4/1/2009     377300   234000  336900  243500
# 138         7/1/2009     437700   217700  317800  243800
# 139        10/1/2009     465800   235300  318800  232900

# %%
# plot graph of housing prices by region 10 Year

plt.rcParams["figure.figsize"]=[20,10]
plt.rcParams["font.size"]=16

fig4, ax4 = plt.subplots()

ax4.set_xlabel("Date (Quarters)")
ax4.set_ylabel("Avg Home Prices")

data_west = regional_10yr["West"]
data_south = regional_10yr["South"]
data_ne = regional_10yr["Northeast"]
data_mw = regional_10yr["Midwest"]

x_axis4 = regional_10yr["Date (Quarterly)"]

west_trend = plt.plot(x_axis4,data_west,color='g',marker = "o")
south_trend = plt.plot(x_axis4,data_south,color='r',marker = "o")
ne_trend = plt.plot(x_axis4,data_ne,color='b',marker = "o")
mw_trend = plt.plot(x_axis4,data_mw,color='c',marker = "o")

plt.legend(loc="best")

ax4.grid(True)
fig4.autofmt_xdate()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Perform the ANOVA 10 Yr
stats.f_oneway(regional_10yr["West"], regional_10yr["South"], regional_10yr["Northeast"], regional_10yr["Midwest"])
# Out:
# F_onewayResult(statistic=99.03914548430888, pvalue=6.161046559808874e-36)

# %%
# Perform the ANOVA 10 Yr (minus NE)
stats.f_oneway(regional_10yr["West"], regional_10yr["South"], regional_10yr["Midwest"])
# Out:
# F_onewayResult(statistic=50.46478221336024, pvalue=1.5753537397448586e-16)

# %%
# Create a boxplot to compare means
regional_20yr.boxplot("mosq", by="treatment", figsize=(20, 10))

# %%
#-------------------------------------------------------------------------

# %%
regional_housing.head()
# Out:
#   Date (Quarterly)  Northeast  Midwest   West  South
# 0         1/1/1975      47300    41800  42300  38000
# 1         4/1/1975      46400    44000  43600  39800
# 2         7/1/1975      47400    42900  43600  39200
# 3        10/1/1975      47700    44500  47400  41300
# 4         1/1/1976      48600    45100  49200  43000

# %%
# Normalize US Data 

#US_housing_v_unemployment["Avg Home Price Chg"] = US_housing_v_unemployment["Avg Home Price"].pct_change(periods=1, fill_method='pad', limit=None, freq=None)
#US_housing_v_unemployment["Unemployment Rate Chg"] = US_housing_v_unemployment["Unemployment Rate (%)"].pct_change(periods=1, fill_method='pad', limit=None, freq=None)

#mean_AHP = US_housing_v_unemployment["Avg Home Price Chg"].mean()
#mean_UER = US_housing_v_unemployment["Unemployment Rate Chg"].mean()

#US_housing_v_unemployment["Avg Home Price Chg (Norm)"] = US_housing_v_unemployment["Avg Home Price Chg"] - mean_AHP
#US_housing_v_unemployment["Unemployment Rate Chg (Norm)"] = US_housing_v_unemployment["Unemployment Rate Chg"] - mean_UER

#US_housing_v_unemployment.head()

# %%
# import fed funds rate
fed_funds_file=pd.read_csv("FedFundsRateQuarterly.csv")


fed_funds=fed_funds_file.rename(columns={"DATE":"Date (Quarterly)","FEDFUNDS":"Fed Funds Rate"})
fed_funds.head()
fed_funds_regional = pd.concat([regional_housing, fed_funds], axis=1)
fed_funds_regional.head()
# Out:
#   Date (Quarterly)  Northeast  Midwest   West  South Date (Quarterly)  \
# 0         1/1/1975      47300    41800  42300  38000       1975-01-01
# 1         4/1/1975      46400    44000  43600  39800       1975-04-01
# 2         7/1/1975      47400    42900  43600  39200       1975-07-01
# 3        10/1/1975      47700    44500  47400  41300       1975-10-01
# 4         1/1/1976      48600    45100  49200  43000       1976-01-01
#
#    Fed Funds Rate
# 0        6.303333
# 1        5.420000
# 2        6.160000
# 3        5.413333
# 4        4.826667

# %%
# Normalize the Regional Data

fed_funds_regional["NE Quarterly Change"]= fed_funds_regional["Northeast"].pct_change(periods=1,fill_method='pad',limit=None,freq=None)
fed_funds_regional["MW Quarterly Change"]= fed_funds_regional["Midwest"].pct_change(periods=1,fill_method='pad',limit=None,freq=None)
fed_funds_regional["W Quarterly Change"]= fed_funds_regional["West"].pct_change(periods=1,fill_method='pad',limit=None,freq=None)
fed_funds_regional["S Quarterly Change"]= fed_funds_regional["South"].pct_change(periods=1,fill_method='pad',limit=None,freq=None)
fed_funds_regional["Fed Funds Quarterly Change"]= fed_funds_regional["Fed Funds Rate"].pct_change(periods=1,fill_method='pad',limit=None,freq=None)

mean_NE = fed_funds_regional["NE Quarterly Change"].mean()
mean_MW = fed_funds_regional["MW Quarterly Change"].mean()
mean_W = fed_funds_regional["W Quarterly Change"].mean()
mean_S = fed_funds_regional["S Quarterly Change"].mean()
mean_Fed = fed_funds_regional["Fed Funds Quarterly Change"].mean()

fed_funds_regional["Avg NE Price Chg (Norm)"] = fed_funds_regional["NE Quarterly Change"] - mean_NE
fed_funds_regional["Avg MW Price Chg (Norm)"] = fed_funds_regional["MW Quarterly Change"] - mean_MW
fed_funds_regional["Avg W Price Chg (Norm)"] = fed_funds_regional["W Quarterly Change"] - mean_W
fed_funds_regional["Avg S Price Chg (Norm)"] = fed_funds_regional["S Quarterly Change"] - mean_S
fed_funds_regional["Avg Fed Funds Chg (Norm)"] = fed_funds_regional["Fed Funds Rate"] - mean_Fed


fed_funds_regional.head()
# Out:
#   Date (Quarterly)  Northeast  Midwest   West  South Date (Quarterly)  \
# 0         1/1/1975      47300    41800  42300  38000       1975-01-01
# 1         4/1/1975      46400    44000  43600  39800       1975-04-01
# 2         7/1/1975      47400    42900  43600  39200       1975-07-01
# 3        10/1/1975      47700    44500  47400  41300       1975-10-01
# 4         1/1/1976      48600    45100  49200  43000       1976-01-01
#
#    Fed Funds Rate  NE Quarterly Change  MW Quarterly Change  \
# 0        6.303333                  NaN                  NaN
# 1        5.420000            -0.019027             0.052632
# 2        6.160000             0.021552            -0.025000
# 3        5.413333             0.006329             0.037296
# 4        4.826667             0.018868             0.013483
#
#    W Quarterly Change  S Quarterly Change  Fed Funds Quarterly Change  \
# 0                 NaN                 NaN                         NaN
# 1            0.030733            0.047368                   -0.140137
# 2            0.000000           -0.015075                    0.136531
# 3            0.087156            0.053571                   -0.121212
# 4            0.037975            0.041162                   -0.108374
#
#    Avg NE Price Chg (Norm)  Avg MW Price Chg (Norm)  Avg W Price Chg (Norm)  \
# 0                      NaN                      NaN                     NaN
# 1                -0.038583                 0.038886                0.015960
# 2                 0.001996                -0.038746               -0.014773
# 3                -0.013227                 0.023550                0.072383
# 4                -0.000688                -0.000263                0.023202
#
#    Avg S Price Chg (Norm)  Avg Fed Funds Chg (Norm)
# 0                     NaN                  6.290441
# 1                0.034082                  5.407108
# 2               -0.028362                  6.147108
# 3                0.040285                  5.400441
# 4                0.027876                  4.813774
